# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
newframe = pd.read_csv("steganography_experiments.csv")

# %%
newframe.head()
# Out:
#    poisoned nodes  Model poisoning  Training Accuracy  Training Loss  \
# 0               0                5             85.569         0.3110
# 1               1                5             85.272         0.4395
# 2               2                5             80.025         0.5590
# 3               3                5             84.777         0.4515
# 4               4                5             87.081         0.3760
#
#    Test Accuracy  Test Loss  Processing Time  Unnamed: 7  Training Loss.1  \
# 0        54.8610     1.6236         1192.395         NaN            0.456
# 1        58.9280     1.3155         1283.840         NaN            0.435
# 2        57.3405     1.2640         1313.330         NaN            0.647
# 3        58.5220     1.2920         1220.745         NaN            0.487
# 4        60.4165     1.3095         1298.835         NaN            0.362
#
#    Training Acc  Test Loss.1  Test Acc  Processing Time.1  Unnamed: 13  \
# 0        75.841        1.464    58.730            1231.37          NaN
# 1        86.089        1.325    58.531            1313.76          NaN
# 2        77.475        1.247    56.547            1332.41          NaN
# 3        82.673        1.236    58.314            1243.27          NaN
# 4        87.727        1.312    60.119            1274.30          NaN
#
#    Training Loss.2  Training Acc.1  Test Loss.2  Test Acc.1  Processing Time.2
# 0            0.166          95.297       1.7832      50.992            1153.42
# 1            0.444          84.455       1.3060      59.325            1253.92
# 2            0.471          82.574       1.2810      58.134            1294.25
# 3            0.416          86.881       1.3480      58.730            1198.22
# 4            0.390          86.435       1.3070      60.714            1323.37

# %%
newframe.drop(newframe.columns[7:], axis=1, inplace=True)

# %%
newframe
# Out:
#     poisoned nodes  Model poisoning  Training Accuracy  Training Loss  \
# 0                0                5            85.5690        0.31100
# 1                1                5            85.2720        0.43950
# 2                2                5            80.0250        0.55900
# 3                3                5            84.7770        0.45150
# 4                4                5            87.0810        0.37600
# 5                0               10            85.5690        0.31100
# 6                1               10            85.0975        0.48250
# 7                2               10            84.7770        0.44850
# 8                3               10            83.8190        0.43600
# 9                4               10            86.3115        0.41650
# 10               0               15            85.5690        0.31100
# 11               1               15            83.5890        0.51400
# 12               2               15            84.1830        0.44850
# 13               3               15            84.6035        0.44950
# 14               4               15            87.6725        0.37850
# 15               0               20            85.5690        0.31100
# 16               1               20            83.9830        0.48200
# 17               2               20            84.2075        0.45650
# 18               3               20            84.9250        0.44200
# 19               4               20            81.7320        0.51925
# 20               0               25            85.5690        0.31100
# 21               1               25            82.1530        0.60050
# 22               2               25            84.2120        0.50650
# 23               3               25            84.6530        0.45800
# 24               4               25            86.5120        0.38700
# 25               0               30            85.5690        0.31100
# 26               1               30            82.1000        0.55850
# 27               2               30            83.5140        0.50750
# 28               3               30            85.1975        0.42700
# 29               4               30            89.2240        0.32950
#
#     Test Accuracy  Test Loss  Processing Time
# 0         54.8610     1.6236        1192.3950
# 1         58.9280     1.3155        1283.8400
# 2         57.3405     1.2640        1313.3300
# 3         58.5220     1.2920        1220.7450
# 4         60.4165     1.3095        1298.8350
# 5         54.8610     1.6236        1192.3950
# 6         58.6555     1.3515        1305.7450
# 7         59.1265     1.3265        1178.6700
# 8         58.8290     1.3095        1137.0550
# 9         58.6300     1.3635         981.1950
# 10        54.8610     1.6236        1192.3950
# 11        59.7215     1.3375        1198.5350
# 12        61.2550     1.2865        1115.8600
# 13        58.8285     1.3410        1259.2550
# 14        58.9200     1.3200        1137.0750
# 15        54.8610     1.6236        1192.3950
# 16        60.7135     1.3190        1216.2450
# 17        59.0275     1.3660         961.7000
# 18        56.8450     1.3380        1081.4705
# 19        57.3405     1.2690         803.5075
# 20        54.8610     1.6236        1192.3950
# 21        58.9280     1.3055        1190.8700
# 22        58.8285     1.3605        1070.3550
# 23        60.9570     1.3400        1113.5450
# 24        59.1265     1.3200        1195.3300
# 25        54.8610     1.6236        1192.3950
# 26        60.3100     1.2920        1304.6250
# 27        55.8525     1.4170        1083.4150
# 28        58.2335     1.3945        1034.6650
# 29        57.0220     1.4470        1093.8905

# %%
# newframe.replace('#DIV/0!', np.nan, inplace=True)
dtypes = {
    'poisoned nodes': int,
    'Model poisoning': int,
    'Processing Time': float,
    'Training Accuracy': float,
    'Training Loss': float,
    'Test Accuracy': float,
    'Test Loss': float
}
newframe = newframe.astype(dtypes)

# %%
# newframe.set_index(['poisoned nodes', 'Poisoning percentage'])
newframe.set_index('poisoned nodes')
# Out:
#                 Model poisoning  Training Accuracy  Training Loss  \
# poisoned nodes
# 0                             5            85.5690        0.31100
# 1                             5            85.2720        0.43950
# 2                             5            80.0250        0.55900
# 3                             5            84.7770        0.45150
# 4                             5            87.0810        0.37600
# 0                            10            85.5690        0.31100
# 1                            10            85.0975        0.48250
# 2                            10            84.7770        0.44850
# 3                            10            83.8190        0.43600
# 4                            10            86.3115        0.41650
# 0                            15            85.5690        0.31100
# 1                            15            83.5890        0.51400
# 2                            15            84.1830        0.44850
# 3                            15            84.6035        0.44950
# 4                            15            87.6725        0.37850
# 0                            20            85.5690        0.31100
# 1                            20            83.9830        0.48200
# 2                            20            84.2075        0.45650
# 3                            20            84.9250        0.44200
# 4                            20            81.7320        0.51925
# 0                            25            85.5690        0.31100
# 1                            25            82.1530        0.60050
# 2                            25            84.2120        0.50650
# 3                            25            84.6530        0.45800
# 4                            25            86.5120        0.38700
# 0                            30            85.5690        0.31100
# 1                            30            82.1000        0.55850
# 2                            30            83.5140        0.50750
# 3                            30            85.1975        0.42700
# 4                            30            89.2240        0.32950
#
#                 Test Accuracy  Test Loss  Processing Time
# poisoned nodes
# 0                     54.8610     1.6236        1192.3950
# 1                     58.9280     1.3155        1283.8400
# 2                     57.3405     1.2640        1313.3300
# 3                     58.5220     1.2920        1220.7450
# 4                     60.4165     1.3095        1298.8350
# 0                     54.8610     1.6236        1192.3950
# 1                     58.6555     1.3515        1305.7450
# 2                     59.1265     1.3265        1178.6700
# 3                     58.8290     1.3095        1137.0550
# 4                     58.6300     1.3635         981.1950
# 0                     54.8610     1.6236        1192.3950
# 1                     59.7215     1.3375        1198.5350
# 2                     61.2550     1.2865        1115.8600
# 3                     58.8285     1.3410        1259.2550
# 4                     58.9200     1.3200        1137.0750
# 0                     54.8610     1.6236        1192.3950
# 1                     60.7135     1.3190        1216.2450
# 2                     59.0275     1.3660         961.7000
# 3                     56.8450     1.3380        1081.4705
# 4                     57.3405     1.2690         803.5075
# 0                     54.8610     1.6236        1192.3950
# 1                     58.9280     1.3055        1190.8700
# 2                     58.8285     1.3605        1070.3550
# 3                     60.9570     1.3400        1113.5450
# 4                     59.1265     1.3200        1195.3300
# 0                     54.8610     1.6236        1192.3950
# 1                     60.3100     1.2920        1304.6250
# 2                     55.8525     1.4170        1083.4150
# 3                     58.2335     1.3945        1034.6650
# 4                     57.0220     1.4470        1093.8905

# %%
[newframe['Model poisoning'].unique().tolist()]
# Out:
# [[5, 10, 15, 20, 25, 30]]

# %%
xticks = newframe['poisoned nodes'].unique().tolist()
yticks = range(50, 101, 10)

# %% [markdown]
# # plots

# %%
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Training Accuracy').plot(legend=True, xticks=xticks, title='Training Accuracy')
# Out:
# <AxesSubplot:title={'center':'Training Accuracy'}, xlabel='poisoned nodes'>

# %%
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Training Loss').plot(legend=True, xticks=xticks, title='Training Loss')
# Out:
# <AxesSubplot:title={'center':'Training Loss'}, xlabel='poisoned nodes'>

# %%
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Test Accuracy').plot(legend=True, xticks=xticks, title='Test Accuracy')
# Out:
# <AxesSubplot:title={'center':'Test Accuracy'}, xlabel='poisoned nodes'>

# %%
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Test Loss').plot(legend=True, xticks=xticks, title='Test Loss')
# Out:
# <AxesSubplot:title={'center':'Test Loss'}, xlabel='poisoned nodes'>

# %%
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Processing Time').plot(legend=True, xticks=xticks, title='Processing Time')
# Out:
# <AxesSubplot:title={'center':'Processing Time'}, xlabel='poisoned nodes'>

# %%
fig, axs = plt.subplots(1, 2, figsize=(16,6))

newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Training Accuracy').plot(legend=True, xticks=xticks, title='Training Accuracy', ax=axs[0])
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Test Accuracy').plot(legend=True, xticks=xticks, title='Test Accuracy', ax=axs[1])
plt.show()

# %%
fig, axs = plt.subplots(1, 2, figsize=(16,6))

newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Training Loss').plot(legend=True, xticks=xticks, title='Training Loss', ax=axs[0])
newframe.pivot_table(index='poisoned nodes', columns='Model poisoning', values='Test Loss').plot(legend=True, xticks=xticks, title='Test Loss', ax=axs[1])
plt.show()

# %%
#newframe.pivot_table(index='Poisoning percentage', columns='Poisoned Nodes', values='Training Accuracy').plot(legend=True)
